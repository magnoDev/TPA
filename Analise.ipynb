# %%
import pandas as pd
import matplotlib.pyplot as plt

head = ["algorithm", "size", "min", "max", "avg" ]
df = pd.read_csv('./src/output/records.csv')

# %%
selection = df[df.algorithm=='selection']
selection.plot(x='size',y=['max','avg','min'],title="SelectionSort")

# %%
quick = df[df.algorithm=='quick']
quick.plot(x='size',y=['max','avg','min'],title="QuickSort")
